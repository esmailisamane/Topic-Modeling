# %%
import pandas as pd

df_Abstract = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_Abstract.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
len(df_Abstract)
# Out:
# 31306

# %%
first_record = df_Abstract['abstract'][1]
first_record
# Out:
# 'A web-based interface enables medical personnel to remotely monitor medical devices. A monitoring system records operational data and alarms from the medical devices in a file. However, since network connections between the medical devices and the monitoring system are intermittent, the file does not contain a contiguous stream of data for each medical device. The file pauses recording during gaps in network connectivity. The system displays current data, as well as a list of alarms. If medical personnel wish to view more detail about an earlier time or one of the alarms, the system calculates where in the file the medical device data was recorded. This calculation accounts for the discontiguous nature of the data. The system uses times the network connection is made and broken to calculate an index into the file that corresponds to the time of the user-selected alarm.'

# %%
x = len(df_Abstract['abstract'][1])
print(x)
# Out:
# 881

# %%
import torch
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer

# Check if GPU is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the Sentence Transformers model
sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
#sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)

# Adjust UMAP hyperparameters
umap_model = UMAP(n_neighbors=3, 
                  n_components=3, 
                  min_dist=0.05, 
                  metric='cosine', 
                  random_state=100,
                  n_jobs=-1)  # Utilize all available CPU cores for UMAP preprocessing

# Adjust HDBSCAN hyperparameters
hdbscan_model = HDBSCAN( min_cluster_size=80,
                        min_samples=40, 
                        metric='euclidean', 
                        cluster_selection_method='eom', 
                        prediction_data=True)

# Adjust CountVectorizer hyperparameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=10, max_df=0.5)


# c-TF-IDF
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Run Model
topic_model = BERTopic(umap_model=umap_model,
                       embedding_model=sentence_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       ctfidf_model=ctfidf_model,
                       verbose=True)

# Replace 'df['first_claim']' with your data source for the first_claim column
topics, probabilities = topic_model.fit_transform(df_Abstract['abstract'])
# Out:
# Batches:   0%|          | 0/979 [00:00<?, ?it/s]
# 2023-09-23 18:43:42,782 - BERTopic - Transformed documents to Embeddings
# 2023-09-23 18:44:04,425 - BERTopic - Reduced dimensionality
# 2023-09-23 18:44:06,415 - BERTopic - Clustered reduced embeddings

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document": df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})

documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence_c_nmpi = coherence_model.get_coherence()
print("c_npmi is: ",coherence_c_nmpi)
# Out:
# c_npmi is:  -0.1650835367995478

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_CV= coherence_model.get_coherence()
print("C_V is: ", coherence_CV)
# Out:
# C_V is:  0.35482890908014697

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence_u_mass= coherence_model.get_coherence()
print("u_mass is: ", coherence_u_mass)
# Out:
# u_mass is:  -0.5687047678531202

# %%
 topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  16163                             -1_sleep_bed_claim_emr
# 1       0   2160  0_the medical image_medical images_image proce...
# 2       1   1675  1_disclosure relates_disclosed are_disclosure ...
# 3       2   1156  2_the invention relates_present invention is_r...
# 4       3   1128   3_referral_consumer_and health care_the consumer
# 5       4   1053  4_pharmacy_dispensing_the prescription_the med...
# 6       5    497  5_invention provide_present invention provide_...
# 7       6    419              6_glucose_insulin_blood glucose_bolus
# 8       7    383            7_ecg_heart rate_electrocardiogram_lead
# 9       8    353                    8_food_nutritional_diet_of food
# 10      9    349  9_information processing_an information proces...
# 11     10    338  10_alarm_the alarm_an alarm_physiological para...
# 12     11    334  11_fitness_the exercise_an exercise_physical a...
# 13     12    320  12_information management_information manageme...
# 14     13    312     13_vital sign_transmitter_rfid_patient monitor
# 15     14    280  14_processing circuitry_the processing circuit...
# 16     15    257    15_an ultrasound_the ultrasound_ultrasonic_echo
# 17     16    230            16_infusion_the infusion_pump_injection
# 18     17    220                     17_cancer_acid_gene_expression
# 19     18    204      18_data records_the access_rights_the request
# 20     19    193          19_is method_mixed_is method of_is system
# 21     20    193            20_the surgical_robotic_stimulation_hub
# 22     21    187              21_dental_orthodontic_teeth_appliance
# 23     22    167      22_radiation_radiotherapy_treatment plan_beam
# 24     23    163  23_card_drive_personal medical_portable electr...
# 25     24    163  24_information providing_measured data_present...
# 26     25    162            25_speech_breathing_textual_respiration
# 27     26    149  26_interface module_of medical devices_event i...
# 28     27    148  27_clinical trial_trial_the clinical trial_trials
# 29     28    146  28_unstructured_decision support_decision supp...
# 30     29    133  29_pharmacy_prescriptions_the prescription_ful...
# 31     30    131               30_rfid_inventory_enclosure_articles
# 32     31    130  31_wellness_and wellness_personalized health_h...
# 33     32    124  32_device measures_quality of life_of life_con...
# 34     33    115              33_cancer_expression_biomarkers_tumor
# 35     34    113  34_the blood pressure_wave_pressure of_oxygena...
# 36     35    100  35_display image_display processor_multiple di...
# 37     36    100        36_blood flow_coronary_vascular_vasculature
# 38     37     93  37_computing device configured_pump_system for...
# 39     38     89  38_deformation_brain of_bone_the invention rel...
# 40     39     87  39_reality_the surgical_augmented reality_augm...
# 41     40     86  40_biological information_vital data_living bo...
# 42     41     86  41_vessel_blood vessel_the blood vessel_contra...
# 43     42     85             42_mr_mri_magnetic resonance_resonance
# 44     43     84   43_radiation_the radiation_control apparatus_ray
# 45     44     84             44_ml_or therapy_chronic_heart failure
# 46     45     82  45_stress_the stress_experienced_embodiments m...
# 47     46     82  46_wearable device_the wearable device_the wea...
#
#                                        Representation  \
# 0   [sleep, bed, claim, emr, claims, eye, transact...
# 1   [the medical image, medical images, image proc...
# 2   [disclosure relates, disclosed are, disclosure...
# 3   [the invention relates, present invention is, ...
# 4   [referral, consumer, and health care, the cons...
# 5   [pharmacy, dispensing, the prescription, the m...
# 6   [invention provide, present invention provide,...
# 7   [glucose, insulin, blood glucose, bolus, diabe...
# 8   [ecg, heart rate, electrocardiogram, lead, ven...
# 9   [food, nutritional, diet, of food, meal, nutri...
# 10  [information processing, an information proces...
# 11  [alarm, the alarm, an alarm, physiological par...
# 12  [fitness, the exercise, an exercise, physical ...
# 13  [information management, information managemen...
# 14  [vital sign, transmitter, rfid, patient monito...
# 15  [processing circuitry, the processing circuitr...
# 16  [an ultrasound, the ultrasound, ultrasonic, ec...
# 17  [infusion, the infusion, pump, injection, inje...
# 18  [cancer, acid, gene, expression, immune, genes...
# 19  [data records, the access, rights, the request...
# 20  [is method, mixed, is method of, is system, an...
# 21  [the surgical, robotic, stimulation, hub, arm,...
# 22  [dental, orthodontic, teeth, appliance, implan...
# 23  [radiation, radiotherapy, treatment plan, beam...
# 24  [card, drive, personal medical, portable elect...
# 25  [information providing, measured data, present...
# 26  [speech, breathing, textual, respiration, pulm...
# 27  [interface module, of medical devices, event i...
# 28  [clinical trial, trial, the clinical trial, tr...
# 29  [unstructured, decision support, decision supp...
# 30  [pharmacy, prescriptions, the prescription, fu...
# 31  [rfid, inventory, enclosure, articles, cabinet...
# 32  [wellness, and wellness, personalized health, ...
# 33  [device measures, quality of life, of life, co...
# 34  [cancer, expression, biomarkers, tumor, breast...
# 35  [the blood pressure, wave, pressure of, oxygen...
# 36  [display image, display processor, multiple di...
# 37  [blood flow, coronary, vascular, vasculature, ...
# 38  [computing device configured, pump, system for...
# 39  [deformation, brain of, bone, the invention re...
# 40  [reality, the surgical, augmented reality, aug...
# 41  [biological information, vital data, living bo...
# 42  [vessel, blood vessel, the blood vessel, contr...
# 43  [mr, mri, magnetic resonance, resonance, magne...
# 44  [radiation, the radiation, control apparatus, ...
# 45  [ml, or therapy, chronic, heart failure, forec...
# 46  [stress, the stress, experienced, embodiments ...
# 47  [wearable device, the wearable device, the wea...
#
#                                   Representative_Docs
# 0   [An image-guided tool and method for ophthalmi...
# 1   [Methods and systems for automatically analyzi...
# 2   [Disclosed are methods comprising: receiving d...
# 3   [The present invention discloses methods and a...
# 4   [A computer-implemented method includes receiv...
# 5   [Systems and methods are provided for facilita...
# 6   [Certain embodiments of the present invention ...
# 7   [A controller for an insulin infusion device i...
# 8   [A monitoring device includes a housing config...
# 9   [This invention is a device and system for mon...
# 10  [An image processing apparatus includes a gene...
# 11  [Methods, systems, and devices for patient mon...
# 12  [Systems, methods, and computer-readable mediu...
# 13  [A computerized system is described which can ...
# 14  [A monitoring system comprises a module having...
# 15  [A medical information processing apparatus ac...
# 16  [A microscopic change in structure of sound ve...
# 17  [Methods and systems of patient treatment are ...
# 18  [This disclosure describes methods of predicti...
# 19  [A method and apparatus for personally control...
# 20  [A care system and associated methods are prov...
# 21  [An implantable medical device is disclosed. A...
# 22  [A method for preparing for and providing dent...
# 23  [In the field of radiotherapy, methods for dos...
# 24  [The system and method for portable medical re...
# 25  [A data acquisition and data reduction system ...
# 26  [A method of predicting survivability of a pat...
# 27  [In general, the invention provides techniques...
# 28  [Methods, systems, and apparatus, including co...
# 29  [A system and method for evaluating patient ri...
# 30  [The present invention relates to prescription...
# 31  [An automatic data collection system tracks me...
# 32  [A system is disclosed that uses profiles of u...
# 33  [A system for providing feedback to an individ...
# 34  [Methods and compositions are provided for the...
# 35  [A system for monitoring medical conditions in...
# 36  [A system incorporates inpatient and outpatien...
# 37  [The present invention provides a technique fo...
# 38  [A fluid infusion system as described herein i...
# 39  [The invention relates to a method for determi...
# 40  [An augmented reality display system and metho...
# 41  [In a vital data utilization system ( 100 ), (...
# 42  [Provided are methods for estimating a Reserve...
# 43  [Systems and methods for evaluating an anatomi...
# 44  [A control apparatus which receives a radiatio...
# 45  [Mechanisms are provided for training a hybrid...
# 46  [In particular embodiments, a method includes ...
# 47  [An intelligent wearable device is disclosed. ...

# %%
#adding topics and probs for eachdoc in dataset
df_Abstract['topics'] = topics
df_Abstract['prob'] = probabilities
df_Abstract_topic=df_Abstract[["publication_number","title","abstract","sub_classes","sub_class","topics","prob"]]
df_Abstract_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                                 abstract  \
# 0      A reality interactive responding system, compr...
# 1      A web-based interface enables medical personne...
# 2      A facility for predicting patient outcomes on ...
# 3      Through a physician&#39;s portal, a platform c...
# 4      Infusion systems, infusion devices, and relate...
# ...                                                  ...
# 31301  A user authentication system performs user rec...
# 31302  A diagnosis support apparatus for diagnosis of...
# 31303  A patient appointment schedule is generated fo...
# 31304  The present invention relates to a method for ...
# 31305  A method including a healthcare server of a he...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']       3  1.000000
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']      10  0.788830
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      -1  0.000000
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']       3  1.000000
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      -1  0.000000
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']      -1  0.000000
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']       0  0.882754
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      -1  0.000000
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']      -1  0.000000
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']       3  0.988738
#
# [31306 rows x 7 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_Abstract_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_Abstract_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_Abstract_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %%
test1 = df_Abstract_test.loc[0, 'abstract']
test1
# Out:
# 'A physiological sensor has light emitting sources, each activated by addressing at least one row and at least one column of an electrical grid. The light emitting sources are capable of transmitting light of multiple wavelengths and a detector is responsive to the transmitted light after attenuation by body tissue.'

# %%
import numpy as np 

# Find topics
num_of_topics = 5
similar_topics, similarity = topic_model.find_topics(test1, top_n=num_of_topics); 

# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')

for idx, topic_idx in enumerate(similar_topics):
    topic = topic_model.get_topic(topic_idx)
    keywords = ' '.join(str(keyword) for keyword in topic[0])
    print(f"Topic {idx+1}: {keywords}")
# Out:
# The top 5 similar topics are [40, 13, 10, 46, 7], and the similarities are [0.67 0.67 0.65 0.64 0.64]
# Topic 1: biological information 0.6552945015816999
# Topic 2: vital sign 0.3686265162369979
# Topic 3: alarm 0.5276353125994339
# Topic 4: wearable device 0.5503394171785392
# Topic 5: ecg 0.6001228641181893

# %%
filter_topics_filter = df_Abstract_topic[df_Abstract_topic['topics'] == 40]
filter_topics_filter = filter_topics_filter.sort_values('prob', ascending=False)
filter_topics_filter
# Out:
#       publication_number                                              title  \
# 318       US2020145183A1  Physiological information system, physiologica...
# 23871     US2022167894A1  Physiological state control apparatus, physiol...
# 23243     US2010222650A1              Biological signal measuring apparatus
# 23214     US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 22051     US2009187392A1  System and method for monitoring a health cond...
# ...                  ...                                                ...
# 14572     US2013218592A1  Systems and methods for facilitating consolida...
# 4153      US2003172009A1                          Consumables supply system
# 10386     US2017307705A1  3d ute imaging using variable-te stack-of-spir...
# 29892     US2020060656A1                        Ultrasound diagnosis device
# 29002     US2015182124A1  Subject information acquisition apparatus and ...
#
#                                                 abstract  \
# 318    A physiological information system includes: a...
# 23871  A physiological state control apparatus includ...
# 23243  A biological signal measuring apparatus includ...
# 23214  Biological outcomes are detected and/or predic...
# 22051  An ingestible bolus may be disposed within the...
# ...                                                  ...
# 14572  According to various embodiments, veterinary c...
# 4153   In a consumables supply management system in w...
# 10386  Some aspects of the present disclosure relate ...
# 29892  A Doppler waveform generation unit 30 obtains ...
# 29002  A subject information acquisition apparatus co...
#
#                         sub_classes         sub_class  topics      prob
# 318      ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']      40  1.000000
# 23871     ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']      40  1.000000
# 23243     ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']      40  1.000000
# 23214    ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']      40  1.000000
# 22051  ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']      40  1.000000
# ...                             ...               ...     ...       ...
# 14572    ['G16H70/40', 'G16H20/10']  ['G16H', 'G16H']      40  0.990709
# 4153    ['G16H40/20', 'G06Q20/203']  ['G16H', 'G06Q']      40  0.948795
# 10386   ['G01R33/561', 'G16H30/40']  ['G01R', 'G16H']      40  0.946748
# 29892     ['A61B8/06', 'G16H50/30']  ['A61B', 'G16H']      40  0.945517
# 29002     ['A61B5/00', 'G16H30/40']  ['A61B', 'G16H']      40  0.941676
#
# [86 rows x 7 columns]

# %%
# Define the range of topic IDs you want to retrieve documents for
selected_topic_range =[40, 13, 10, 46, 7]  # Replace with your desired range of topic IDs

# Create an empty DataFrame to store the top 10 documents
top_10_documents_test1 = pd.DataFrame()

# Iterate through the selected topic IDs
for selected_topic_id in selected_topic_range:
    # Filter the dataset based on the current topic ID
    filtered_df = df_Abstract_topic[df_Abstract_topic['topics'] == selected_topic_id]
    
    # Sort the filtered dataset by similarity scores in descending order
    sorted_df = filtered_df.sort_values(by='prob', ascending=False)
    
    # Retrieve the top 10 documents for the current topic
    top_10_for_topic = sorted_df.head(10)
    
    # Append the top 10 documents for the current topic to the result DataFrame
    top_10_documents_test1 = top_10_documents_test1.append(top_10_for_topic)

# Display the top 10 documents for all selected topics
top_10_documents_test1
# Out:
#       publication_number                                              title  \
# 318       US2020145183A1  Physiological information system, physiologica...
# 23871     US2022167894A1  Physiological state control apparatus, physiol...
# 23243     US2010222650A1              Biological signal measuring apparatus
# 23214     US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 22051     US2009187392A1  System and method for monitoring a health cond...
# 21784     US2014200413A1  Biological information management module, slee...
# 21380     US2014103110A1  Automatic touch identification system and meth...
# 21281     US2014077945A1  Biological information notifying apparatus, bi...
# 21061     US2014025309A1  Calibration system with human-like response ac...
# 20494     US2019150853A1  Biological information processing device and b...
# 23166     US2010198083A1  Random Body Movement Cancellation for Non-Cont...
# 26676     US2019239800A1  Systems and Methods for Detecting and Characte...
# 20680     US2013278414A1  Biometric attribute anomoly detection system w...
# 12069     US2021217531A1           Cloud-connected ring-based sensor system
# 20774     US2013303863A1                       Patient Monitoring Apparatus
# 11432     US2018206722A1                              Medical data bracelet
# 21580     US2014148138A1  Method for transmitting physiological detectio...
# 10157     US2017259072A1            System architecture for medical implant
# 21829     US2014206950A1                                  Ward cloud system
# 10083     US2007135855A1  Patient management device for portably interfa...
# 31134     US2016213261A1  Method and device for improving prediction and...
# 8118      US2004236188A1  Method and apparatus for monitoring using a ma...
# 11939     US2021202061A1  Synchronizing physiological measurement data s...
# 23491     US2010286490A1  Interactive patient monitoring system using sp...
# 11702     US2021161393A1                            Temperature measurement
# 23572     US2010317931A1  Method, Device and Computer Program Product fo...
# 11473     US2018225417A1          Cognitive notification for mental support
# 11271     US2018168463A1  Exercise triggered cardiovascular pressure mea...
# 11109     US2018132776A1  Systems and methods for estimating and predict...
# 10713     US2018008208A1                      Patient-Assisted Alarm System
# 501       US2020163628A1  Noninvasive sensor system with visual infograp...
# 1540      US2016259905A1  Wearable electronic device and method for cont...
# 26861     US2019279069A1                         Travel health optimization
# 25586     US2022367031A1              Health monitoring and coaching system
# 25549     US2022367059A1  System and method for wellness assessment of a...
# 25522     US2022359073A1  Edge-intelligent Iot-based Wearable Device For...
# 25055     US2022310225A1  Health management apparatus and method for pro...
# 24050     US2022192556A1  Predictive, diagnostic and therapeutic applica...
# 23309     US2010241465A1  Systems and methods for sensor-enhanced health...
# 22567     US2010023348A1  Remotely taking real-time programmatic actions...
# 31281     US2016242664A1  An apparatus and method for evaluating multich...
# 26614     US2019231316A1  Diagnosis and monitoring of myocardial infarct...
# 22837     US2010115002A1  Customizing diagnostic codes and descriptions ...
# 22967     US2010145206A1                     Alternans and cardiac ischemia
# 23024     US2010156898A1  System and method for lesion-specific coronary...
# 10635     US2017360310A1                   Congenital heart disease monitor
# 10541     US2017340235A1  Computer-aided localization of site of origin ...
# 23236     US2010217144A1  Diagnostic and predictive system and methodolo...
# 10418     US2017311867A1  System for the analysis of the daily heart rhy...
# 10410     US2017311883A1              Cardio-respiratory fitness assessment
#
#                                                 abstract  \
# 318    A physiological information system includes: a...
# 23871  A physiological state control apparatus includ...
# 23243  A biological signal measuring apparatus includ...
# 23214  Biological outcomes are detected and/or predic...
# 22051  An ingestible bolus may be disposed within the...
# 21784  A biological information management module inc...
# 21380  An automatic identification system for communi...
# 21281  A biological information notifying apparatus o...
# 21061  Methods are provided for calibrating stimulus-...
# 20494  A biological information processing device and...
# 23166  A method and system for cancelling body moveme...
# 26676  Various systems are disclosed herein for detec...
# 20680  A system, methods and server for monitoring he...
# 12069  A cloud-connected ring-based sensor system inc...
# 20774  A patient monitoring system including a sensin...
# 11432  A system for vital sign data management and tr...
# 21580  A method for transmitting physiological detect...
# 10157  Aspects of the subject matter described in thi...
# 21829  A ward cloud system comprises an intelligent c...
# 10083  A patient management device for portably inter...
# 31134  Devices, methods and systems for predicting an...
# 8118   A method and an apparatus for use in monitorin...
# 11939  There is provided a method in a collector devi...
# 23491  Systems, methods and techniques are described ...
# 11702  An apparatus is provided for receiving an indi...
# 23572  A method, device, and computer program product...
# 11473  Systems and methods are disclosed for detectin...
# 11271  Systems, devices disclosed provide example met...
# 11109  Systems and methods for estimating emotional s...
# 10713  In the present invention, a system and associa...
# 501    A sensor system for obtaining and displaying i...
# 1540   A method includes determining whether the elec...
# 26861  A geographic location to which a user intends ...
# 25586  A system is disclosed that monitors participan...
# 25549  A system, method, and apparatus for assessing ...
# 25522  A wearable physiological monitoring system com...
# 25055  A health management apparatus based on a neuro...
# 24050  Methods, systems, and computer-readable media ...
# 23309  Systems and methods are discussed for providin...
# 22567  Health metrics can be received from at least o...
# 31281  An evaluating method for ECG signals is provid...
# 26614  An ECG system acquires ECG signals for the pro...
# 22837  An ECG data management system is provided whic...
# 22967  One or more electrocardiographic signals are d...
# 23024  Methods and systems utilizing the data provide...
# 10635  A congenital heart disease monitor utilizes a ...
# 10541  A method for quantifying, during pacemapping, ...
# 23236  A plurality of ECG Superscore formulae, create...
# 10418  An analysis system for analysis of the balance...
# 10410  Methods and systems for assessing cardio-respi...
#
#                           sub_classes         sub_class  topics  prob
# 318        ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']      40   1.0
# 23871       ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']      40   1.0
# 23243       ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']      40   1.0
# 23214      ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']      40   1.0
# 22051    ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']      40   1.0
# 21784      ['G16H40/60', 'G16H40/60']  ['G16H', 'G16H']      40   1.0
# 21380       ['G06K7/00', 'G16H40/20']  ['G06K', 'G16H']      40   1.0
# 21281       ['A61B5/00', 'G16H40/63']  ['A61B', 'G16H']      40   1.0
# 21061      ['G06F19/00', 'G16H40/63']  ['G06F', 'G16H']      40   1.0
# 20494      ['A61B5/024', 'G16H50/30']  ['A61B', 'G16H']      40   1.0
# 23166     ['A61B5/0205', 'G16H40/67']  ['A61B', 'G16H']      13   1.0
# 26676       ['A61B5/11', 'G16H15/00']  ['A61B', 'G16H']      13   1.0
# 20680      ['G16H40/67', 'G08B21/02']  ['G16H', 'G08B']      13   1.0
# 12069  ['G16H50/20', 'A61B2560/0209']  ['G16H', 'A61B']      13   1.0
# 20774       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']      13   1.0
# 11432       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']      13   1.0
# 21580      ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']      13   1.0
# 10157       ['G16H40/67', 'H04W4/80']  ['G16H', 'H04W']      13   1.0
# 21829     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']      13   1.0
# 10083    ['G16H40/67', 'A61N1/37252']  ['G16H', 'A61N']      13   1.0
# 31134     ['A61B5/0205', 'G16H50/20']  ['A61B', 'G16H']      10   1.0
# 8118       ['G16H50/50', 'G16H15/00']  ['G16H', 'G16H']      10   1.0
# 11939       ['G06F1/10', 'G16H20/30']  ['G06F', 'G16H']      10   1.0
# 23491      ['G10L15/00', 'G16H40/67']  ['G10L', 'G16H']      10   1.0
# 11702      ['G16H40/60', 'G01K13/20']  ['G16H', 'G01K']      10   1.0
# 23572      ['G16H40/63', 'A61B5/369']  ['G16H', 'A61B']      10   1.0
# 11473       ['A61B5/16', 'G16H50/70']  ['A61B', 'G16H']      10   1.0
# 11271       ['A61B5/00', 'G16H20/30']  ['A61B', 'G16H']      10   1.0
# 11109      ['A61B5/024', 'G16H50/20']  ['A61B', 'G16H']      10   1.0
# 10713      ['A61B5/026', 'G16H40/63']  ['A61B', 'G16H']      10   1.0
# 501      ['G16H15/00', 'A61B5/14546']  ['G16H', 'A61B']      46   1.0
# 1540      ['G16H20/30', 'A61B5/6831']  ['G16H', 'A61B']      46   1.0
# 26861       ['G06N5/04', 'G16H50/30']  ['G06N', 'G16H']      46   1.0
# 25586      ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']      46   1.0
# 25549    ['G16H50/30', 'G06Q30/0267']  ['G16H', 'G06Q']      46   1.0
# 25522      ['G16H20/70', 'G16H20/10']  ['G16H', 'G16H']      46   1.0
# 25055       ['A61B5/11', 'G16H30/40']  ['A61B', 'G16H']      46   1.0
# 24050       ['A61B5/11', 'G16H20/70']  ['A61B', 'G16H']      46   1.0
# 23309      ['G06Q40/00', 'G16H50/30']  ['G06Q', 'G16H']      46   1.0
# 22567      ['G16H40/67', 'G06Q10/00']  ['G16H', 'G06Q']      46   1.0
# 31281     ['G16H50/20', 'A61B5/7267']  ['G16H', 'A61B']       7   1.0
# 26614      ['A61B5/044', 'G16H50/30']  ['A61B', 'G16H']       7   1.0
# 22837      ['G16H10/40', 'G16H15/00']  ['G16H', 'G16H']       7   1.0
# 22967       ['A61B5/02', 'G16H50/20']  ['A61B', 'G16H']       7   1.0
# 23024      ['G06T15/08', 'G16H50/30']  ['G06T', 'G16H']       7   1.0
# 10635       ['A61B5/00', 'G16H50/30']  ['A61B', 'G16H']       7   1.0
# 10541       ['A61B5/00', 'G16H50/70']  ['A61B', 'G16H']       7   1.0
# 23236     ['A61B5/0402', 'G16H50/30']  ['A61B', 'G16H']       7   1.0
# 10418      ['G06F19/00', 'G16H15/00']  ['G06F', 'G16H']       7   1.0
# 10410      ['G16H20/30', 'A61B5/742']  ['G16H', 'A61B']       7   1.0

# %%
num_records = top_10_documents_test1.shape[0]
num_records
# Out:
# 50

# %% [markdown]
# # list of 100 queries

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Assuming you have a list of 100 queries in test
for query in df_Abstract_test['abstract'][:num_samples_to_predict]:
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))

# Now, the 'results' list contains the similar topics and similarities for each query
# You can access the results for a specific query like this:
for i, (similar_topics, similarity) in enumerate(results):
    print(f"Query {i + 1}: Similar Topics {similar_topics}, Similarity {similarity}")
# Out:
# Query 1: Similar Topics [40, 13, 10, 46, 7], Similarity [0.67092514, 0.66505456, 0.64937407, 0.6383254, 0.6357091]
# Query 2: Similar Topics [13, 46, 39, 7, 10], Similarity [0.6222541, 0.6102503, 0.5832952, 0.57399035, 0.5695604]
# Query 3: Similar Topics [39, 20, 3, -1, 0], Similarity [0.627025, 0.61962545, 0.6120764, 0.6087836, 0.60691154]
# Query 4: Similar Topics [36, 5, 7, 41, 34], Similarity [0.8323266, 0.7833832, 0.7461008, 0.7445706, 0.736279]
# Query 5: Similar Topics [13, 7, 10, 25, 26], Similarity [0.6255849, 0.6190642, 0.6053225, 0.6048085, 0.60412645]
# Query 6: Similar Topics [13, 40, 10, 6, -1], Similarity [0.7210678, 0.7097218, 0.6871717, 0.68660045, 0.6714189]
# Query 7: Similar Topics [11, 46, 20, -1, 31], Similarity [0.759723, 0.7257217, 0.67620224, 0.66556543, 0.66291046]
# Query 8: Similar Topics [11, 46, 20, 13, 7], Similarity [0.7967641, 0.71084565, 0.70571953, 0.6802571, 0.67850447]
# Query 9: Similar Topics [4, 30, -1, 20, 0], Similarity [0.67571807, 0.67570114, 0.6699429, 0.6665815, 0.6662392]
# Query 10: Similar Topics [0, 41, 39, 15, 42], Similarity [0.71965337, 0.69377816, 0.6833035, 0.67434216, 0.6659161]
# Query 11: Similar Topics [17, 33, 5, 41, 37], Similarity [0.7596297, 0.74105775, 0.63334507, 0.6240794, 0.6163502]
# Query 12: Similar Topics [25, 45, 14, -1, 10], Similarity [0.61847544, 0.606277, 0.5807922, 0.5743239, 0.5732616]
# Query 13: Similar Topics [46, 13, 10, 7, 34], Similarity [0.7764493, 0.7435272, 0.73308456, 0.71980256, 0.7067177]
# Query 14: Similar Topics [10, 46, 25, 13, -1], Similarity [0.74175525, 0.73547566, 0.72799695, 0.7266662, 0.7104449]
# Query 15: Similar Topics [10, 13, -1, 32, 25], Similarity [0.71239173, 0.70551926, 0.68173194, 0.68104553, 0.67015827]
# Query 16: Similar Topics [6, 20, -1, 10, 13], Similarity [0.7553214, 0.6548189, 0.64523953, 0.6407964, 0.63525224]
# Query 17: Similar Topics [6, 16, 46, 10, 13], Similarity [0.7539793, 0.66636825, 0.6615135, 0.66094184, 0.65990186]
# Query 18: Similar Topics [31, 10, 3, 27, 4], Similarity [0.72049177, 0.70296925, 0.6995958, 0.69531834, 0.6852492]
# Query 19: Similar Topics [10, 13, 46, 26, 1], Similarity [0.66601, 0.6392951, 0.6368974, 0.6317198, 0.62377983]
# Query 20: Similar Topics [2, 29, 24, -1, 38], Similarity [0.81556773, 0.7569315, 0.742771, 0.72291803, 0.7213763]
# Query 21: Similar Topics [33, 17, 38, 2, 24], Similarity [0.72714585, 0.6481465, 0.6299353, 0.620852, 0.6201307]
# Query 22: Similar Topics [21, 20, 14, 38, 37], Similarity [0.6708877, 0.58059794, 0.5437914, 0.5413, 0.5223304]
# Query 23: Similar Topics [31, 3, -1, 12, 27], Similarity [0.7963667, 0.78100795, 0.7496174, 0.73747796, 0.72914296]
# Query 24: Similar Topics [7, 10, 34, 25, 13], Similarity [0.69285595, 0.67005026, 0.6611247, 0.63282156, 0.6133686]
# Query 25: Similar Topics [45, 25, -1, 10, 3], Similarity [0.7308469, 0.69794774, 0.68716013, 0.6698657, 0.6690912]
# Query 26: Similar Topics [21, 0, 22, -1, 27], Similarity [0.7971614, 0.68872094, 0.6777409, 0.6773655, 0.67007476]
# Query 27: Similar Topics [20, 39, 16, 12, 14], Similarity [0.62263405, 0.6036097, 0.58603734, 0.5814058, 0.5808767]
# Query 28: Similar Topics [26, 13, 32, -1, 23], Similarity [0.83517694, 0.82459104, 0.80709076, 0.7997721, 0.79899716]
# Query 29: Similar Topics [17, 33, 45, 27, 1], Similarity [0.57348096, 0.52210677, 0.5171344, 0.5143651, 0.5016407]
# Query 30: Similar Topics [13, 26, -1, 32, 20], Similarity [0.7302814, 0.7262273, 0.72410274, 0.7210404, 0.7204273]
# Query 31: Similar Topics [12, 28, 44, 3, 14], Similarity [0.70286655, 0.6966314, 0.6958455, 0.686939, 0.684034]
# Query 32: Similar Topics [16, 37, 34, 20, 36], Similarity [0.693921, 0.58805764, 0.58242786, 0.57696676, 0.55935544]
# Query 33: Similar Topics [20, 21, 39, 38, 0], Similarity [0.65922964, 0.62629914, 0.6101312, 0.6087944, 0.5789658]
# Query 34: Similar Topics [1, 18, 23, 32, 2], Similarity [0.7936641, 0.7561957, 0.7559787, 0.74922895, 0.73615724]
# Query 35: Similar Topics [9, 26, 43, 13, 12], Similarity [0.61144006, 0.59185266, 0.5877918, 0.5877434, 0.585338]
# Query 36: Similar Topics [23, 26, 32, 46, 3], Similarity [0.72195774, 0.71722686, 0.7034081, 0.7028086, 0.67710435]
# Query 37: Similar Topics [6, 16, 34, 37, 10], Similarity [0.770509, 0.66416657, 0.62381774, 0.6215804, 0.61471164]
# Query 38: Similar Topics [6, 26, 12, 13, 35], Similarity [0.7523074, 0.7424283, 0.73859084, 0.7376253, 0.71319675]
# Query 39: Similar Topics [10, 13, 46, 25, 7], Similarity [0.7871789, 0.7604159, 0.7474193, 0.74540913, 0.74328804]
# Query 40: Similar Topics [22, 20, 16, 43, 37], Similarity [0.68551636, 0.68449533, 0.6565378, 0.65490997, 0.6519256]
# Query 41: Similar Topics [13, 23, 32, 26, 39], Similarity [0.64058924, 0.6377336, 0.6365711, 0.62982774, 0.61857396]
# Query 42: Similar Topics [21, 0, 44, 22, 37], Similarity [0.75802386, 0.639848, 0.62693846, 0.62348163, 0.62144893]
# Query 43: Similar Topics [2, 29, 24, 13, 5], Similarity [0.71850705, 0.6700231, 0.6601548, 0.6369028, 0.63631624]
# Query 44: Similar Topics [25, 7, -1, 41, 34], Similarity [0.6474683, 0.6236792, 0.62308264, 0.6162507, 0.61466366]
# Query 45: Similar Topics [18, 12, 32, 26, 3], Similarity [0.65162563, 0.65140927, 0.64975107, 0.642507, 0.62923634]
# Query 46: Similar Topics [-1, 28, 10, 40, 25], Similarity [0.7354188, 0.73504937, 0.73025393, 0.72366863, 0.7228271]
# Query 47: Similar Topics [6, 10, 13, 34, 40], Similarity [0.76255715, 0.7344519, 0.7110744, 0.6797252, 0.676013]
# Query 48: Similar Topics [21, 0, 38, 39, 41], Similarity [0.75806826, 0.6791024, 0.64564127, 0.644076, 0.6391487]
# Query 49: Similar Topics [21, 27, 22, 44, 3], Similarity [0.75771147, 0.6356111, 0.62348527, 0.62346745, 0.59946316]
# Query 50: Similar Topics [1, 18, -1, 17, 37], Similarity [0.7218008, 0.6669644, 0.65678775, 0.6567386, 0.6524935]
# Query 51: Similar Topics [2, 24, 38, 29, 32], Similarity [0.75749034, 0.7204741, 0.69118077, 0.6886324, 0.66937715]
# Query 52: Similar Topics [0, 45, 17, -1, 41], Similarity [0.6516365, 0.64646006, 0.6346522, 0.6271148, 0.62191725]
# Query 53: Similar Topics [-1, 40, 25, 45, 37], Similarity [0.7309532, 0.7290232, 0.7258017, 0.7158952, 0.7132087]
# Query 54: Similar Topics [7, 34, 25, 10, 41], Similarity [0.81362784, 0.76245403, 0.75066614, 0.73024565, 0.7256015]
# Query 55: Similar Topics [20, 39, 26, 13, 12], Similarity [0.76802933, 0.70728326, 0.6418589, 0.635846, 0.6284542]
# Query 56: Similar Topics [1, 25, -1, 45, 32], Similarity [0.7600532, 0.6935104, 0.69119763, 0.68563294, 0.6782385]
# Query 57: Similar Topics [21, 20, 38, 39, -1], Similarity [0.72144365, 0.6091374, 0.5850985, 0.5763828, 0.55475736]
# Query 58: Similar Topics [26, 13, 12, 10, 32], Similarity [0.82679164, 0.7957798, 0.79287916, 0.76799977, 0.7646947]
# Query 59: Similar Topics [34, 6, 40, 45, 10], Similarity [0.6831095, 0.66290486, 0.6625317, 0.6574702, 0.65414816]
# Query 60: Similar Topics [21, 20, 36, 41, -1], Similarity [0.7272193, 0.68948627, 0.67685103, 0.6692854, 0.66868305]
# Query 61: Similar Topics [11, 8, 46, 31, 6], Similarity [0.6787226, 0.6139173, 0.6095656, 0.58434, 0.5306885]
# Query 62: Similar Topics [11, 31, 46, -1, 10], Similarity [0.7662712, 0.747319, 0.7305201, 0.71409154, 0.7091702]
# Query 63: Similar Topics [20, 39, 25, 13, 14], Similarity [0.63199705, 0.62725884, 0.6158111, 0.6089417, 0.6032942]
# Query 64: Similar Topics [7, 46, 13, 10, 34], Similarity [0.7229275, 0.7182373, 0.68349314, 0.6828179, 0.67168224]
# Query 65: Similar Topics [9, 40, 13, 26, 46], Similarity [0.5685679, 0.5456104, 0.53196603, 0.52932453, 0.5256118]
# Query 66: Similar Topics [13, 39, 46, 23, 24], Similarity [0.59556055, 0.5925579, 0.59196687, 0.581214, 0.5579922]
# Query 67: Similar Topics [44, 28, 27, -1, 3], Similarity [0.65484357, 0.63714635, 0.62289894, 0.61758447, 0.61485696]
# Query 68: Similar Topics [11, 1, 46, 10, 40], Similarity [0.7444557, 0.7244195, 0.7122946, 0.6726723, 0.6532773]
# Query 69: Similar Topics [13, 26, 30, 40, -1], Similarity [0.66165894, 0.64677763, 0.6420284, 0.62616765, 0.6259834]
# Query 70: Similar Topics [13, 10, -1, 26, 3], Similarity [0.7326752, 0.72501314, 0.72163516, 0.71888125, 0.71178275]
# Query 71: Similar Topics [7, 13, 10, 37, 25], Similarity [0.64741504, 0.6417556, 0.62810606, 0.61387086, 0.6085411]
# Query 72: Similar Topics [46, 11, 30, 13, 8], Similarity [0.6772679, 0.66291714, 0.64880913, 0.6367459, 0.6332952]
# Query 73: Similar Topics [6, 10, 46, 8, 31], Similarity [0.6424438, 0.6209572, 0.6061591, 0.5822524, 0.5788811]
# Query 74: Similar Topics [31, 46, -1, 3, 11], Similarity [0.66415584, 0.65159523, 0.6487435, 0.64480025, 0.63265014]
# Query 75: Similar Topics [12, 32, 26, 3, -1], Similarity [0.7715614, 0.75809926, 0.75778913, 0.75046355, 0.7477902]
# Query 76: Similar Topics [2, 38, 24, 14, 40], Similarity [0.77520216, 0.7645881, 0.76299906, 0.7196292, 0.716051]
# Query 77: Similar Topics [16, 37, 4, 22, -1], Similarity [0.77038634, 0.7232413, 0.7032724, 0.7022622, 0.6937752]
# Query 78: Similar Topics [34, 13, 16, 20, 10], Similarity [0.66522795, 0.65233296, 0.64730036, 0.6458465, 0.63427544]
# Query 79: Similar Topics [10, 6, 25, 40, 13], Similarity [0.63151383, 0.5800515, 0.5655638, 0.5614584, 0.5562619]
# Query 80: Similar Topics [20, 13, -1, 46, 14], Similarity [0.69939715, 0.6567614, 0.6512497, 0.6481047, 0.6479878]
# Query 81: Similar Topics [7, 10, 34, 13, 25], Similarity [0.69868124, 0.67134887, 0.6519182, 0.64095294, 0.63209414]
# Query 82: Similar Topics [10, 13, 3, -1, 34], Similarity [0.7685332, 0.73323464, 0.720858, 0.7142705, 0.6986531]
# Query 83: Similar Topics [39, 21, 0, 38, 41], Similarity [0.70558727, 0.6586341, 0.65828276, 0.6564827, 0.65304506]
# Query 84: Similar Topics [26, 32, 12, 23, 3], Similarity [0.770556, 0.7429278, 0.7168268, 0.7149576, 0.7146516]
# Query 85: Similar Topics [14, 9, 20, 40, 2], Similarity [0.62716955, 0.6162118, 0.6033988, 0.59929395, 0.5982936]
# Query 86: Similar Topics [46, 11, 13, 40, 9], Similarity [0.76462996, 0.74410236, 0.7225046, 0.6955496, 0.6894392]
# Query 87: Similar Topics [17, 33, 37, 1, 27], Similarity [0.6188687, 0.55670387, 0.54837394, 0.5306396, 0.52884233]
# Query 88: Similar Topics [23, 18, 32, 30, 12], Similarity [0.80152905, 0.7265501, 0.6755202, 0.67489284, 0.67421734]
# Query 89: Similar Topics [29, 2, 24, 4, 30], Similarity [0.7528557, 0.7425405, 0.6588782, 0.65868413, 0.647786]
# Query 90: Similar Topics [5, 16, 26, 32, 37], Similarity [0.7816293, 0.77658236, 0.74031776, 0.7237232, 0.71047086]
# Query 91: Similar Topics [20, 12, 14, 0, 39], Similarity [0.76875716, 0.74490297, 0.74433255, 0.74254864, 0.74142206]
# Query 92: Similar Topics [42, 0, 41, 39, 44], Similarity [0.7030528, 0.6999699, 0.6709684, 0.6509896, 0.63878953]
# Query 93: Similar Topics [46, 10, 13, 45, -1], Similarity [0.7845241, 0.76130354, 0.7332501, 0.72861445, 0.72213006]
# Query 94: Similar Topics [10, 34, 40, 46, 7], Similarity [0.7150684, 0.7145005, 0.69454885, 0.6851648, 0.6827973]
# Query 95: Similar Topics [34, 7, 25, 10, 36], Similarity [0.8262118, 0.778288, 0.7493238, 0.7449042, 0.7293481]
# Query 96: Similar Topics [18, 32, 23, 12, -1], Similarity [0.72174203, 0.7158757, 0.70514226, 0.6936697, 0.67482674]
# Query 97: Similar Topics [5, -1, 32, 12, 18], Similarity [0.7477776, 0.6199566, 0.6112227, 0.6066322, 0.6059607]
# Query 98: Similar Topics [16, 37, 1, -1, 2], Similarity [0.71190834, 0.6940111, 0.68819296, 0.6537262, 0.6503873]
# Query 99: Similar Topics [10, 25, 13, 14, 7], Similarity [0.7330996, 0.71164584, 0.70774096, 0.70394564, 0.7000139]
# Query 100: Similar Topics [12, 32, 26, 18, 3], Similarity [0.7756299, 0.76646924, 0.7602129, 0.7562051, 0.75480884]

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Create an empty DataFrame to store the results
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Assuming you have a list of 100 queries in 'df_Abstract_test'
for i, (query, publication_number, abstract, class_codes) in enumerate(zip(df_Abstract_test['abstract'][:num_samples_to_predict], 
                                                    df_Abstract_test['publication_numbers'][:num_samples_to_predict],
                                                    df_Abstract_test['abstract'][:num_samples_to_predict],
                                                    df_Abstract_test['class_codes'][:num_samples_to_predict])):
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))
    
    # Store the results in the DataFrame
    result_df_q = result_df_q.append({
        'query_abstract': query,
        'query_predicted_topics': similar_topics,
        'query_publication_numbers': publication_number,
        'query_class_codes': class_codes
    }, ignore_index=True)
    
result_df_q
# Out:
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 95           US20230017310A1
# 96           US20230091925A1
# 97           US20230010638A1
# 98           US20230009812A1
# 99           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 95  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 96  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 97  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 98  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 99  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                        query_abstract query_predicted_topics
# 0   A physiological sensor has light emitting sour...    [40, 13, 10, 46, 7]
# 1   A wearable monitoring device includes a band c...    [13, 46, 39, 7, 10]
# 2   A number of improvements are provided relating...     [39, 20, 3, -1, 0]
# 3   Embodiments include a system for determining c...     [36, 5, 7, 41, 34]
# 4   A community based response system for providin...    [13, 7, 10, 25, 26]
# ..                                                ...                    ...
# 95  Features are disclosed for remote storage of m...   [18, 32, 23, 12, -1]
# 96  Some of the embodiments herein provide a seaml...    [5, -1, 32, 12, 18]
# 97  A method and system is disclosed for operating...     [16, 37, 1, -1, 2]
# 98  A patient monitor including a physiological me...    [10, 25, 13, 14, 7]
# 99  A system to manage records in a healthcare pra...    [12, 32, 26, 18, 3]
#
# [100 rows x 4 columns]

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'abstract', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_abstract']
    predicted_topics = row['query_predicted_topics']
    
    for topic_id in predicted_topics:
        # Filter 'df_Abstract_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_Abstract_topic[df_Abstract_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'result_df' DataFrame
        for _, doc_row in topic_documents.iterrows():
            result_df = result_df.append({
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_abstract': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'abstract': doc_row['abstract'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }, ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020145183A1  Physiological information system, physiologica...
# 1        US2022167894A1  Physiological state control apparatus, physiol...
# 2        US2010222650A1              Biological signal measuring apparatus
# 3        US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 4        US2009187392A1  System and method for monitoring a health cond...
# ...                 ...                                                ...
# 4995     US2021390595A1                   Electronic reputation management
# 4996     US2021398627A1  Systems and methods for health information mes...
# 4997     US2021407679A1  Deep-learning based certainty qualification in...
# 4998     US2021407683A1  Method and system for remote health monitoring...
# 4999     US2021407630A1                     Clinical Trial Protocol Portal
#
#                                                abstract  \
# 0     A physiological information system includes: a...
# 1     A physiological state control apparatus includ...
# 2     A biological signal measuring apparatus includ...
# 3     Biological outcomes are detected and/or predic...
# 4     An ingestible bolus may be disposed within the...
# ...                                                 ...
# 4995  At least one computer-readable medium on which...
# 4996  Messages having patient healthcare information...
# 4997  A method for assessing diagnostic certainty in...
# 4998  A method, a system, and a non-transitory stora...
# 4999  A system and a computer-implemented method for...
#
#                        sub_classes         sub_class topics  prob  \
# 0       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     40   1.0
# 1        ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 2        ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']     40   1.0
# 3       ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']     40   1.0
# 4     ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']     40   1.0
# ...                            ...               ...    ...   ...
# 4995    ['G06Q30/02', 'G16H40/20']  ['G06Q', 'G16H']      3   1.0
# 4996    ['G16H40/67', 'H04L67/01']  ['G16H', 'H04L']      3   1.0
# 4997   ['G16H15/00', 'G06F40/253']  ['G16H', 'G06F']      3   1.0
# 4998    ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']      3   1.0
# 4999    ['G16H80/00', 'G16H40/20']  ['G16H', 'G16H']      3   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract query_predicted_topics
# 0     A physiological sensor has light emitting sour...                   [40]
# 1     A physiological sensor has light emitting sour...                   [40]
# 2     A physiological sensor has light emitting sour...                   [40]
# 3     A physiological sensor has light emitting sour...                   [40]
# 4     A physiological sensor has light emitting sour...                   [40]
# ...                                                 ...                    ...
# 4995  A system to manage records in a healthcare pra...                    [3]
# 4996  A system to manage records in a healthcare pra...                    [3]
# 4997  A system to manage records in a healthcare pra...                    [3]
# 4998  A system to manage records in a healthcare pra...                    [3]
# 4999  A system to manage records in a healthcare pra...                    [3]
#
# [5000 rows x 11 columns]

# %%
result_df['query_class_codes'][0]
# Out:
# 'A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/7221,A61B5/14532,G16H40/00,A61B5/14546,G16H40/60,A61B5/68,A61B2562/08,H,A61B1/00,A61B2562/221,A61B5/7475,A61B2562/18,A61B5/746,A61B5/7405,H05K,G16H40/67,A61B,Y10,A61B5/6813,Y,A61B2562/185,G16H10/40,A61B5/6826,A61B5/02,A61B5/0002,A61B5/1455,A61B5/6832,A,A61B5/7235,A61B5/6801,A61B5/7278,G16H,A61B5/026,A61B5/742,A61B2562/22,A61B5/024,G16,A61B5/02416,A61B5/683,A61B5/0015,A61B5/6825,Y10S,A61B5/1495,A61B5/72,A61B5/0261,A61B2562/085,A61B2562/222,A61B5/7275,A61B5/00,A61B5/145,A61B5/74,G16H10/00,H05K999/99,A61B5/7246,Y10S439/909,A61B5/14552,A61B5/6838,A61B5/6815,A61B5/7271,H05K999/00,A61B5/02427,A61B5/0205,Y10S439/00,A61B5/0022,A61B5/6814,A61B2562/00,H05'

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020145183A1  Physiological information system, physiologica...
# 1        US2022167894A1  Physiological state control apparatus, physiol...
# 2        US2010222650A1              Biological signal measuring apparatus
# 3        US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 4        US2009187392A1  System and method for monitoring a health cond...
# ...                 ...                                                ...
# 4995     US2021390595A1                   Electronic reputation management
# 4996     US2021398627A1  Systems and methods for health information mes...
# 4997     US2021407679A1  Deep-learning based certainty qualification in...
# 4998     US2021407683A1  Method and system for remote health monitoring...
# 4999     US2021407630A1                     Clinical Trial Protocol Portal
#
#                                                abstract  \
# 0     A physiological information system includes: a...
# 1     A physiological state control apparatus includ...
# 2     A biological signal measuring apparatus includ...
# 3     Biological outcomes are detected and/or predic...
# 4     An ingestible bolus may be disposed within the...
# ...                                                 ...
# 4995  At least one computer-readable medium on which...
# 4996  Messages having patient healthcare information...
# 4997  A method for assessing diagnostic certainty in...
# 4998  A method, a system, and a non-transitory stora...
# 4999  A system and a computer-implemented method for...
#
#                        sub_classes         sub_class topics  prob  \
# 0       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     40   1.0
# 1        ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 2        ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']     40   1.0
# 3       ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']     40   1.0
# 4     ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']     40   1.0
# ...                            ...               ...    ...   ...
# 4995    ['G06Q30/02', 'G16H40/20']  ['G06Q', 'G16H']      3   1.0
# 4996    ['G16H40/67', 'H04L67/01']  ['G16H', 'H04L']      3   1.0
# 4997   ['G16H15/00', 'G06F40/253']  ['G16H', 'G06F']      3   1.0
# 4998    ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']      3   1.0
# 4999    ['G16H80/00', 'G16H40/20']  ['G16H', 'G16H']      3   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [40]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [40]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [40]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [40]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [40]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 4995                    [3]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996                    [3]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997                    [3]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998                    [3]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999                    [3]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [5000 rows x 12 columns]

# %%
import ast


# Create a new column to store the common code
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Convert the sub_classes string to a list
    sub_classes = ast.literal_eval(sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str
    
    # Debugging statements
    #print(f'Row {index}: sub_classes={sub_classes}, query_codes_G16H={query_codes_G16H}, common_codes={common_codes_str}')

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020145183A1  Physiological information system, physiologica...
# 1        US2022167894A1  Physiological state control apparatus, physiol...
# 2        US2010222650A1              Biological signal measuring apparatus
# 3        US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 4        US2009187392A1  System and method for monitoring a health cond...
# ...                 ...                                                ...
# 4995     US2021390595A1                   Electronic reputation management
# 4996     US2021398627A1  Systems and methods for health information mes...
# 4997     US2021407679A1  Deep-learning based certainty qualification in...
# 4998     US2021407683A1  Method and system for remote health monitoring...
# 4999     US2021407630A1                     Clinical Trial Protocol Portal
#
#                                                abstract  \
# 0     A physiological information system includes: a...
# 1     A physiological state control apparatus includ...
# 2     A biological signal measuring apparatus includ...
# 3     Biological outcomes are detected and/or predic...
# 4     An ingestible bolus may be disposed within the...
# ...                                                 ...
# 4995  At least one computer-readable medium on which...
# 4996  Messages having patient healthcare information...
# 4997  A method for assessing diagnostic certainty in...
# 4998  A method, a system, and a non-transitory stora...
# 4999  A system and a computer-implemented method for...
#
#                        sub_classes         sub_class topics  prob  \
# 0       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     40   1.0
# 1        ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 2        ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']     40   1.0
# 3       ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']     40   1.0
# 4     ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']     40   1.0
# ...                            ...               ...    ...   ...
# 4995    ['G06Q30/02', 'G16H40/20']  ['G06Q', 'G16H']      3   1.0
# 4996    ['G16H40/67', 'H04L67/01']  ['G16H', 'H04L']      3   1.0
# 4997   ['G16H15/00', 'G06F40/253']  ['G16H', 'G06F']      3   1.0
# 4998    ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']      3   1.0
# 4999    ['G16H80/00', 'G16H40/20']  ['G16H', 'G16H']      3   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [40]
# 1                      [40]
# 2                      [40]
# 3                      [40]
# 4                      [40]
# ...                     ...
# 4995                    [3]
# 4996                    [3]
# 4997                    [3]
# 4998                    [3]
# 4999                    [3]
#
#                                        query_codes_G16H     exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...  G16H40/67,G16H40/67
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# ...                                                 ...                  ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H40/20
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H40/20
#
# [5000 rows x 13 columns]

# %%
# result_df.sample(n=100)

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020145183A1  Physiological information system, physiologica...
# 1        US2022167894A1  Physiological state control apparatus, physiol...
# 2        US2010222650A1              Biological signal measuring apparatus
# 3        US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 4        US2009187392A1  System and method for monitoring a health cond...
# ...                 ...                                                ...
# 4995     US2021390595A1                   Electronic reputation management
# 4996     US2021398627A1  Systems and methods for health information mes...
# 4997     US2021407679A1  Deep-learning based certainty qualification in...
# 4998     US2021407683A1  Method and system for remote health monitoring...
# 4999     US2021407630A1                     Clinical Trial Protocol Portal
#
#                                                abstract  \
# 0     A physiological information system includes: a...
# 1     A physiological state control apparatus includ...
# 2     A biological signal measuring apparatus includ...
# 3     Biological outcomes are detected and/or predic...
# 4     An ingestible bolus may be disposed within the...
# ...                                                 ...
# 4995  At least one computer-readable medium on which...
# 4996  Messages having patient healthcare information...
# 4997  A method for assessing diagnostic certainty in...
# 4998  A method, a system, and a non-transitory stora...
# 4999  A system and a computer-implemented method for...
#
#                        sub_classes         sub_class topics  prob  \
# 0       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     40   1.0
# 1        ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 2        ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']     40   1.0
# 3       ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']     40   1.0
# 4     ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']     40   1.0
# ...                            ...               ...    ...   ...
# 4995    ['G06Q30/02', 'G16H40/20']  ['G06Q', 'G16H']      3   1.0
# 4996    ['G16H40/67', 'H04L67/01']  ['G16H', 'H04L']      3   1.0
# 4997   ['G16H15/00', 'G06F40/253']  ['G16H', 'G06F']      3   1.0
# 4998    ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']      3   1.0
# 4999    ['G16H80/00', 'G16H40/20']  ['G16H', 'G16H']      3   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [40]
# 1                      [40]
# 2                      [40]
# 3                      [40]
# 4                      [40]
# ...                     ...
# 4995                    [3]
# 4996                    [3]
# 4997                    [3]
# 4998                    [3]
# 4999                    [3]
#
#                                        query_codes_G16H     exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...  G16H40/67,G16H40/67
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# ...                                                 ...                  ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H40/20
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H40/20
#
#       count_exact_match
# 0                    14
# 1                    14
# 2                    14
# 3                    14
# 4                    14
# ...                 ...
# 4995                 21
# 4996                 21
# 4997                 21
# 4998                 21
# 4999                 21
#
# [5000 rows x 14 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230238130A1']
filtered_df
# Out:
#    publication_number                                              title  \
# 0      US2020145183A1  Physiological information system, physiologica...
# 1      US2022167894A1  Physiological state control apparatus, physiol...
# 2      US2010222650A1              Biological signal measuring apparatus
# 3      US2010211404A1  Methods and Systems for Real-Time RRi Values P...
# 4      US2009187392A1  System and method for monitoring a health cond...
# 5      US2014200413A1  Biological information management module, slee...
# 6      US2014103110A1  Automatic touch identification system and meth...
# 7      US2014077945A1  Biological information notifying apparatus, bi...
# 8      US2014025309A1  Calibration system with human-like response ac...
# 9      US2019150853A1  Biological information processing device and b...
# 10     US2010198083A1  Random Body Movement Cancellation for Non-Cont...
# 11     US2019239800A1  Systems and Methods for Detecting and Characte...
# 12     US2013278414A1  Biometric attribute anomoly detection system w...
# 13     US2021217531A1           Cloud-connected ring-based sensor system
# 14     US2013303863A1                       Patient Monitoring Apparatus
# 15     US2018206722A1                              Medical data bracelet
# 16     US2014148138A1  Method for transmitting physiological detectio...
# 17     US2017259072A1            System architecture for medical implant
# 18     US2014206950A1                                  Ward cloud system
# 19     US2007135855A1  Patient management device for portably interfa...
# 20     US2016213261A1  Method and device for improving prediction and...
# 21     US2004236188A1  Method and apparatus for monitoring using a ma...
# 22     US2021202061A1  Synchronizing physiological measurement data s...
# 23     US2010286490A1  Interactive patient monitoring system using sp...
# 24     US2021161393A1                            Temperature measurement
# 25     US2010317931A1  Method, Device and Computer Program Product fo...
# 26     US2018225417A1          Cognitive notification for mental support
# 27     US2018168463A1  Exercise triggered cardiovascular pressure mea...
# 28     US2018132776A1  Systems and methods for estimating and predict...
# 29     US2018008208A1                      Patient-Assisted Alarm System
# 30     US2020163628A1  Noninvasive sensor system with visual infograp...
# 31     US2016259905A1  Wearable electronic device and method for cont...
# 32     US2019279069A1                         Travel health optimization
# 33     US2022367031A1              Health monitoring and coaching system
# 34     US2022367059A1  System and method for wellness assessment of a...
# 35     US2022359073A1  Edge-intelligent Iot-based Wearable Device For...
# 36     US2022310225A1  Health management apparatus and method for pro...
# 37     US2022192556A1  Predictive, diagnostic and therapeutic applica...
# 38     US2010241465A1  Systems and methods for sensor-enhanced health...
# 39     US2010023348A1  Remotely taking real-time programmatic actions...
# 40     US2016242664A1  An apparatus and method for evaluating multich...
# 41     US2019231316A1  Diagnosis and monitoring of myocardial infarct...
# 42     US2010115002A1  Customizing diagnostic codes and descriptions ...
# 43     US2010145206A1                     Alternans and cardiac ischemia
# 44     US2010156898A1  System and method for lesion-specific coronary...
# 45     US2017360310A1                   Congenital heart disease monitor
# 46     US2017340235A1  Computer-aided localization of site of origin ...
# 47     US2010217144A1  Diagnostic and predictive system and methodolo...
# 48     US2017311867A1  System for the analysis of the daily heart rhy...
# 49     US2017311883A1              Cardio-respiratory fitness assessment
#
#                                              abstract  \
# 0   A physiological information system includes: a...
# 1   A physiological state control apparatus includ...
# 2   A biological signal measuring apparatus includ...
# 3   Biological outcomes are detected and/or predic...
# 4   An ingestible bolus may be disposed within the...
# 5   A biological information management module inc...
# 6   An automatic identification system for communi...
# 7   A biological information notifying apparatus o...
# 8   Methods are provided for calibrating stimulus-...
# 9   A biological information processing device and...
# 10  A method and system for cancelling body moveme...
# 11  Various systems are disclosed herein for detec...
# 12  A system, methods and server for monitoring he...
# 13  A cloud-connected ring-based sensor system inc...
# 14  A patient monitoring system including a sensin...
# 15  A system for vital sign data management and tr...
# 16  A method for transmitting physiological detect...
# 17  Aspects of the subject matter described in thi...
# 18  A ward cloud system comprises an intelligent c...
# 19  A patient management device for portably inter...
# 20  Devices, methods and systems for predicting an...
# 21  A method and an apparatus for use in monitorin...
# 22  There is provided a method in a collector devi...
# 23  Systems, methods and techniques are described ...
# 24  An apparatus is provided for receiving an indi...
# 25  A method, device, and computer program product...
# 26  Systems and methods are disclosed for detectin...
# 27  Systems, devices disclosed provide example met...
# 28  Systems and methods for estimating emotional s...
# 29  In the present invention, a system and associa...
# 30  A sensor system for obtaining and displaying i...
# 31  A method includes determining whether the elec...
# 32  A geographic location to which a user intends ...
# 33  A system is disclosed that monitors participan...
# 34  A system, method, and apparatus for assessing ...
# 35  A wearable physiological monitoring system com...
# 36  A health management apparatus based on a neuro...
# 37  Methods, systems, and computer-readable media ...
# 38  Systems and methods are discussed for providin...
# 39  Health metrics can be received from at least o...
# 40  An evaluating method for ECG signals is provid...
# 41  An ECG system acquires ECG signals for the pro...
# 42  An ECG data management system is provided whic...
# 43  One or more electrocardiographic signals are d...
# 44  Methods and systems utilizing the data provide...
# 45  A congenital heart disease monitor utilizes a ...
# 46  A method for quantifying, during pacemapping, ...
# 47  A plurality of ECG Superscore formulae, create...
# 48  An analysis system for analysis of the balance...
# 49  Methods and systems for assessing cardio-respi...
#
#                        sub_classes         sub_class topics  prob  \
# 0       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     40   1.0
# 1        ['A61B5/16', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 2        ['G16H20/40', 'A61B5/74']  ['G16H', 'A61B']     40   1.0
# 3       ['G16H10/60', 'A61B5/316']  ['G16H', 'A61B']     40   1.0
# 4     ['G16H40/67', 'A61B5/02055']  ['G16H', 'A61B']     40   1.0
# 5       ['G16H40/60', 'G16H40/60']  ['G16H', 'G16H']     40   1.0
# 6        ['G06K7/00', 'G16H40/20']  ['G06K', 'G16H']     40   1.0
# 7        ['A61B5/00', 'G16H40/63']  ['A61B', 'G16H']     40   1.0
# 8       ['G06F19/00', 'G16H40/63']  ['G06F', 'G16H']     40   1.0
# 9       ['A61B5/024', 'G16H50/30']  ['A61B', 'G16H']     40   1.0
# 10     ['A61B5/0205', 'G16H40/67']  ['A61B', 'G16H']     13   1.0
# 11       ['A61B5/11', 'G16H15/00']  ['A61B', 'G16H']     13   1.0
# 12      ['G16H40/67', 'G08B21/02']  ['G16H', 'G08B']     13   1.0
# 13  ['G16H50/20', 'A61B2560/0209']  ['G16H', 'A61B']     13   1.0
# 14       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     13   1.0
# 15       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     13   1.0
# 16      ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     13   1.0
# 17       ['G16H40/67', 'H04W4/80']  ['G16H', 'H04W']     13   1.0
# 18     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     13   1.0
# 19    ['G16H40/67', 'A61N1/37252']  ['G16H', 'A61N']     13   1.0
# 20     ['A61B5/0205', 'G16H50/20']  ['A61B', 'G16H']     10   1.0
# 21      ['G16H50/50', 'G16H15/00']  ['G16H', 'G16H']     10   1.0
# 22       ['G06F1/10', 'G16H20/30']  ['G06F', 'G16H']     10   1.0
# 23      ['G10L15/00', 'G16H40/67']  ['G10L', 'G16H']     10   1.0
# 24      ['G16H40/60', 'G01K13/20']  ['G16H', 'G01K']     10   1.0
# 25      ['G16H40/63', 'A61B5/369']  ['G16H', 'A61B']     10   1.0
# 26       ['A61B5/16', 'G16H50/70']  ['A61B', 'G16H']     10   1.0
# 27       ['A61B5/00', 'G16H20/30']  ['A61B', 'G16H']     10   1.0
# 28      ['A61B5/024', 'G16H50/20']  ['A61B', 'G16H']     10   1.0
# 29      ['A61B5/026', 'G16H40/63']  ['A61B', 'G16H']     10   1.0
# 30    ['G16H15/00', 'A61B5/14546']  ['G16H', 'A61B']     46   1.0
# 31     ['G16H20/30', 'A61B5/6831']  ['G16H', 'A61B']     46   1.0
# 32       ['G06N5/04', 'G16H50/30']  ['G06N', 'G16H']     46   1.0
# 33      ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     46   1.0
# 34    ['G16H50/30', 'G06Q30/0267']  ['G16H', 'G06Q']     46   1.0
# 35      ['G16H20/70', 'G16H20/10']  ['G16H', 'G16H']     46   1.0
# 36       ['A61B5/11', 'G16H30/40']  ['A61B', 'G16H']     46   1.0
# 37       ['A61B5/11', 'G16H20/70']  ['A61B', 'G16H']     46   1.0
# 38      ['G06Q40/00', 'G16H50/30']  ['G06Q', 'G16H']     46   1.0
# 39      ['G16H40/67', 'G06Q10/00']  ['G16H', 'G06Q']     46   1.0
# 40     ['G16H50/20', 'A61B5/7267']  ['G16H', 'A61B']      7   1.0
# 41      ['A61B5/044', 'G16H50/30']  ['A61B', 'G16H']      7   1.0
# 42      ['G16H10/40', 'G16H15/00']  ['G16H', 'G16H']      7   1.0
# 43       ['A61B5/02', 'G16H50/20']  ['A61B', 'G16H']      7   1.0
# 44      ['G06T15/08', 'G16H50/30']  ['G06T', 'G16H']      7   1.0
# 45       ['A61B5/00', 'G16H50/30']  ['A61B', 'G16H']      7   1.0
# 46       ['A61B5/00', 'G16H50/70']  ['A61B', 'G16H']      7   1.0
# 47     ['A61B5/0402', 'G16H50/30']  ['A61B', 'G16H']      7   1.0
# 48      ['G06F19/00', 'G16H15/00']  ['G06F', 'G16H']      7   1.0
# 49      ['G16H20/30', 'A61B5/742']  ['G16H', 'A61B']      7   1.0
#
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230238130A1
# 2            US20230238130A1
# 3            US20230238130A1
# 4            US20230238130A1
# 5            US20230238130A1
# 6            US20230238130A1
# 7            US20230238130A1
# 8            US20230238130A1
# 9            US20230238130A1
# 10           US20230238130A1
# 11           US20230238130A1
# 12           US20230238130A1
# 13           US20230238130A1
# 14           US20230238130A1
# 15           US20230238130A1
# 16           US20230238130A1
# 17           US20230238130A1
# 18           US20230238130A1
# 19           US20230238130A1
# 20           US20230238130A1
# 21           US20230238130A1
# 22           US20230238130A1
# 23           US20230238130A1
# 24           US20230238130A1
# 25           US20230238130A1
# 26           US20230238130A1
# 27           US20230238130A1
# 28           US20230238130A1
# 29           US20230238130A1
# 30           US20230238130A1
# 31           US20230238130A1
# 32           US20230238130A1
# 33           US20230238130A1
# 34           US20230238130A1
# 35           US20230238130A1
# 36           US20230238130A1
# 37           US20230238130A1
# 38           US20230238130A1
# 39           US20230238130A1
# 40           US20230238130A1
# 41           US20230238130A1
# 42           US20230238130A1
# 43           US20230238130A1
# 44           US20230238130A1
# 45           US20230238130A1
# 46           US20230238130A1
# 47           US20230238130A1
# 48           US20230238130A1
# 49           US20230238130A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 5   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 6   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 7   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 8   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 9   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 10  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 11  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 12  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 13  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 14  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 15  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 16  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 17  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 18  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 19  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 20  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 21  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 22  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 23  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 24  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 25  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 26  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 27  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 28  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 29  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 30  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 31  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 32  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 33  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 34  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 35  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 36  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 37  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 38  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 39  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 40  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 41  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 42  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 43  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 44  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 45  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 46  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 47  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 48  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 49  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
#
#                                        query_abstract query_predicted_topics  \
# 0   A physiological sensor has light emitting sour...                   [40]
# 1   A physiological sensor has light emitting sour...                   [40]
# 2   A physiological sensor has light emitting sour...                   [40]
# 3   A physiological sensor has light emitting sour...                   [40]
# 4   A physiological sensor has light emitting sour...                   [40]
# 5   A physiological sensor has light emitting sour...                   [40]
# 6   A physiological sensor has light emitting sour...                   [40]
# 7   A physiological sensor has light emitting sour...                   [40]
# 8   A physiological sensor has light emitting sour...                   [40]
# 9   A physiological sensor has light emitting sour...                   [40]
# 10  A physiological sensor has light emitting sour...                   [13]
# 11  A physiological sensor has light emitting sour...                   [13]
# 12  A physiological sensor has light emitting sour...                   [13]
# 13  A physiological sensor has light emitting sour...                   [13]
# 14  A physiological sensor has light emitting sour...                   [13]
# 15  A physiological sensor has light emitting sour...                   [13]
# 16  A physiological sensor has light emitting sour...                   [13]
# 17  A physiological sensor has light emitting sour...                   [13]
# 18  A physiological sensor has light emitting sour...                   [13]
# 19  A physiological sensor has light emitting sour...                   [13]
# 20  A physiological sensor has light emitting sour...                   [10]
# 21  A physiological sensor has light emitting sour...                   [10]
# 22  A physiological sensor has light emitting sour...                   [10]
# 23  A physiological sensor has light emitting sour...                   [10]
# 24  A physiological sensor has light emitting sour...                   [10]
# 25  A physiological sensor has light emitting sour...                   [10]
# 26  A physiological sensor has light emitting sour...                   [10]
# 27  A physiological sensor has light emitting sour...                   [10]
# 28  A physiological sensor has light emitting sour...                   [10]
# 29  A physiological sensor has light emitting sour...                   [10]
# 30  A physiological sensor has light emitting sour...                   [46]
# 31  A physiological sensor has light emitting sour...                   [46]
# 32  A physiological sensor has light emitting sour...                   [46]
# 33  A physiological sensor has light emitting sour...                   [46]
# 34  A physiological sensor has light emitting sour...                   [46]
# 35  A physiological sensor has light emitting sour...                   [46]
# 36  A physiological sensor has light emitting sour...                   [46]
# 37  A physiological sensor has light emitting sour...                   [46]
# 38  A physiological sensor has light emitting sour...                   [46]
# 39  A physiological sensor has light emitting sour...                   [46]
# 40  A physiological sensor has light emitting sour...                    [7]
# 41  A physiological sensor has light emitting sour...                    [7]
# 42  A physiological sensor has light emitting sour...                    [7]
# 43  A physiological sensor has light emitting sour...                    [7]
# 44  A physiological sensor has light emitting sour...                    [7]
# 45  A physiological sensor has light emitting sour...                    [7]
# 46  A physiological sensor has light emitting sour...                    [7]
# 47  A physiological sensor has light emitting sour...                    [7]
# 48  A physiological sensor has light emitting sour...                    [7]
# 49  A physiological sensor has light emitting sour...                    [7]
#
#                                      query_codes_G16H     exact_match_code  \
# 0   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...  G16H40/67,G16H40/67
# 1   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 5   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...  G16H40/60,G16H40/60
# 6   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 7   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 8   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 9   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 10  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 11  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 12  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 13  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 14  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 15  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 16  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...  G16H40/67,G16H40/67
# 17  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 18  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 19  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 20  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 21  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 22  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 23  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 24  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/60
# 25  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 26  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 27  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 28  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 29  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 30  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 31  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 32  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 33  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 34  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 35  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 36  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 37  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 38  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 39  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# 40  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 41  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 42  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H10/40
# 43  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 44  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 45  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 46  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 47  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 48  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 49  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
#
#     count_exact_match
# 0                  14
# 1                  14
# 2                  14
# 3                  14
# 4                  14
# 5                  14
# 6                  14
# 7                  14
# 8                  14
# 9                  14
# 10                 14
# 11                 14
# 12                 14
# 13                 14
# 14                 14
# 15                 14
# 16                 14
# 17                 14
# 18                 14
# 19                 14
# 20                 14
# 21                 14
# 22                 14
# 23                 14
# 24                 14
# 25                 14
# 26                 14
# 27                 14
# 28                 14
# 29                 14
# 30                 14
# 31                 14
# 32                 14
# 33                 14
# 34                 14
# 35                 14
# 36                 14
# 37                 14
# 38                 14
# 39                 14
# 40                 14
# 41                 14
# 42                 14
# 43                 14
# 44                 14
# 45                 14
# 46                 14
# 47                 14
# 48                 14
# 49                 14
